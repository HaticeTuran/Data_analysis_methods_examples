# %% [markdown]
# <a href="https://colab.research.google.com/github/HaticeTuran/Data_analysis_methods_examples/blob/main/Hatice_Turan_INF506_UE12_ipynb_adl%C4%B1_not_defterinin_kopyas%C4%B1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # INF506 Methoden der Datenanalyse - ÜBUNG 12 - 06.12.2022
#
# **Matrikelnummer**\
# **Vorname, Name**
#
#
# Lesen Sie die Datendatei ein. Weisen Sie die Daten einem Pandas-Datenframe zu.
# Die Datei enthält gemessene Orte und Flächen von Sonnenfleckengruppen zwischen 1976 und 1996, für zwei aufeinanderfolgende Sonnenaktivitätszyklen. Die Orte sind nach Längen- und Breitengraden geordnet.

# %%
import pandas as pd
import numpy as np
from datetime import datetime
from matplotlib import pyplot as plt

# %%
path = './data2.txt'

# %%
df = pd.read_csv(path,sep="\s+")
df
# Out:
#        i    yr  mo  da  hr  mi  se     id  pr1  pr2  ua   ws    lat     lon  \
# 0      g  1976   1   1   0   0   0    675    4    9   3    5  -8.40   33.95
# 1      g  1976  12  31  23  59  59    675    4    9   3    5  -8.40   33.95
# 2      g  1977   1   1   0   0   0    675    4    9   3    5  -8.40   33.95
# 3      g  1976   1  12  12  11  35    675    4    9   3    5  -8.40   33.95
# 4      g  1976   1  12  12  11  35    676   10   80  15  127 -11.45  284.27
# ...   ..   ...  ..  ..  ..  ..  ..    ...  ...  ...  ..  ...    ...     ...
# 57676  g  1996  12  22   8  10   0  8007a    0    6   0    3  -7.28  176.21
# 57677  g  1996  12  23   2  35   0   8004    9   49  16   90   5.77  251.93
# 57678  g  1996  12  23   2  35   0   8007    2   11   2   13   5.18  240.00
# 57679  g  1996  12  24  11  16  49   8008    1    5   1    3 -18.96  168.17
# 57680  g  1996  12  26   8  31  32  8008a    0    2   0    1 -22.36  148.04
#
#          lcm      pa    dcen
# 0      36.89  261.68  0.6024
# 1      36.89  261.68  0.6024
# 2      36.89  261.68  0.6024
# 3      36.89  261.68  0.6024
# 4     -72.80  100.68  0.9537
# ...      ...     ...     ...
# 57676 -11.77  115.09  0.2245
# 57677  73.95  276.56  0.9637
# 57678  62.02  276.89  0.8878
# 57679   8.23  205.06  0.3212
# 57680  12.96  211.18  0.4025
#
# [57681 rows x 17 columns]

# %% [markdown]
# **i**: Means that this data belong to sunspot *groups*, not to individual sunspots
# **yr, mo, da, hr, mi, se**: year, month, day, hour, minute, second
# **id**: ID number of the sunspot group
# **pr1, pr2**: Projected group-area quantities. Just ignore them for this task
# **ua**: Umbral area of sunspot group (umbra is the darkest central region of a sunspot)
# **ws**: Whole-spot area of sunspot group (in millionths of the visible solar hemispheric area)
# **lat**: Latitude (degrees)
# **lon**: Longitude (degrees)
# **lcm**: Longitudinal distance from the Sun's central meridian
# **pa**: Position angle (irrelevant now)
# **dcen**: Distance from the centre of Sun's disc measured in units of the solar radius

# %% [markdown]
# # Preprocessing steps

# %%
df.loc[(df.se > 59),'se'] = 59

# %%
# Eliminating missing data, which are indicated by 999999.
df = df[~(df == 999999).any(axis='columns')]

# %%
# Filter according to lcm
#df.drop([df['lcm'] < 60].index, inplace=True)
df = df[np.abs(df.lcm) <= 70]

# %%
# Clean zero-area groups
df = df[~(df.ws == 0)]
df = df[~(df.ua == 0)]

# %% [markdown]
# Arrange each date and time element into a DateTime object. You can use [ datetime(...) ] directly within a for loop.

# %%
lst = []
for i in range(len(df['yr'])):
  lst.append(datetime(df['yr'].iloc[i], df["mo"].iloc[i], df["da"].iloc[i], df["hr"].iloc[i], df["mi"].iloc[i], df["se"].iloc[i] ))
df.insert(0, "Date Time", lst, True)
#df["date_time"]=lst
df
# Out:
#                 Date Time  i    yr  mo  da  hr  mi  se    id  pr1  pr2   ua  \
# 0     1976-01-01 00:00:00  g  1976   1   1   0   0   0   675    4    9    3
# 1     1976-12-31 23:59:59  g  1976  12  31  23  59  59   675    4    9    3
# 2     1977-01-01 00:00:00  g  1977   1   1   0   0   0   675    4    9    3
# 3     1976-01-12 12:11:35  g  1976   1  12  12  11  35   675    4    9    3
# 6     1976-01-14 01:13:30  g  1976   1  14   1  13  30   676  128  700  106
# ...                   ... ..   ...  ..  ..  ..  ..  ..   ...  ...  ...  ...
# 57672 1996-12-21 05:57:00  g  1996  12  21   5  57   0  8007    3   23    2
# 57674 1996-12-22 08:10:00  g  1996  12  22   8  10   0  8004   15   82   17
# 57675 1996-12-22 08:10:00  g  1996  12  22   8  10   0  8007    4   20    3
# 57678 1996-12-23 02:35:00  g  1996  12  23   2  35   0  8007    2   11    2
# 57679 1996-12-24 11:16:49  g  1996  12  24  11  16  49  8008    1    5    1
#
#         ws    lat     lon    lcm      pa    dcen
# 0        5  -8.40   33.95  36.89  261.68  0.6024
# 1        5  -8.40   33.95  36.89  261.68  0.6024
# 2        5  -8.40   33.95  36.89  261.68  0.6024
# 3        5  -8.40   33.95  36.89  261.68  0.6024
# 6      581 -10.25  283.47 -53.28   99.54  0.8006
# ...    ...    ...     ...    ...     ...     ...
# 57672   14   4.37  238.95  36.58  279.59  0.6050
# 57674   95   5.32  252.25  64.27  276.79  0.9052
# 57675   16   4.35  240.19  52.21  276.94  0.7959
# 57678   13   5.18  240.00  62.02  276.89  0.8878
# 57679    3 -18.96  168.17   8.23  205.06  0.3212
#
# [32697 rows x 18 columns]

# %% [markdown]
# Insert this datetime as the column number 1.

# %% [markdown]
# Set this datetime column as the index column.

# %%
df = df.set_index("Date Time")

# %% [markdown]
# Drop the redundant date and time columns (yr, mo, da, ...)

# %%
df.drop(columns= ['yr', 'mo', 'da', 'hr', 'mi','se'])
# Out:
#                      i    id  pr1  pr2   ua   ws    lat     lon    lcm  \
# Date Time
# 1976-01-01 00:00:00  g   675    4    9    3    5  -8.40   33.95  36.89
# 1976-12-31 23:59:59  g   675    4    9    3    5  -8.40   33.95  36.89
# 1977-01-01 00:00:00  g   675    4    9    3    5  -8.40   33.95  36.89
# 1976-01-12 12:11:35  g   675    4    9    3    5  -8.40   33.95  36.89
# 1976-01-14 01:13:30  g   676  128  700  106  581 -10.25  283.47 -53.28
# ...                 ..   ...  ...  ...  ...  ...    ...     ...    ...
# 1996-12-21 05:57:00  g  8007    3   23    2   14   4.37  238.95  36.58
# 1996-12-22 08:10:00  g  8004   15   82   17   95   5.32  252.25  64.27
# 1996-12-22 08:10:00  g  8007    4   20    3   16   4.35  240.19  52.21
# 1996-12-23 02:35:00  g  8007    2   11    2   13   5.18  240.00  62.02
# 1996-12-24 11:16:49  g  8008    1    5    1    3 -18.96  168.17   8.23
#
#                          pa    dcen
# Date Time
# 1976-01-01 00:00:00  261.68  0.6024
# 1976-12-31 23:59:59  261.68  0.6024
# 1977-01-01 00:00:00  261.68  0.6024
# 1976-01-12 12:11:35  261.68  0.6024
# 1976-01-14 01:13:30   99.54  0.8006
# ...                     ...     ...
# 1996-12-21 05:57:00  279.59  0.6050
# 1996-12-22 08:10:00  276.79  0.9052
# 1996-12-22 08:10:00  276.94  0.7959
# 1996-12-23 02:35:00  276.89  0.8878
# 1996-12-24 11:16:49  205.06  0.3212
#
# [32697 rows x 11 columns]

# %% [markdown]
# Take the absolute value of the latitude (lat) column and insert this as a new column, to the left side of lat.

# %%
abs_lat = df["lat"].abs()
df.insert(df.columns.get_loc("lat"),"abs_lat",abs_lat)
df
# Out:
#                      i    yr  mo  da  hr  mi  se    id  pr1  pr2   ua   ws  \
# Date Time
# 1976-01-01 00:00:00  g  1976   1   1   0   0   0   675    4    9    3    5
# 1976-12-31 23:59:59  g  1976  12  31  23  59  59   675    4    9    3    5
# 1977-01-01 00:00:00  g  1977   1   1   0   0   0   675    4    9    3    5
# 1976-01-12 12:11:35  g  1976   1  12  12  11  35   675    4    9    3    5
# 1976-01-14 01:13:30  g  1976   1  14   1  13  30   676  128  700  106  581
# ...                 ..   ...  ..  ..  ..  ..  ..   ...  ...  ...  ...  ...
# 1996-12-21 05:57:00  g  1996  12  21   5  57   0  8007    3   23    2   14
# 1996-12-22 08:10:00  g  1996  12  22   8  10   0  8004   15   82   17   95
# 1996-12-22 08:10:00  g  1996  12  22   8  10   0  8007    4   20    3   16
# 1996-12-23 02:35:00  g  1996  12  23   2  35   0  8007    2   11    2   13
# 1996-12-24 11:16:49  g  1996  12  24  11  16  49  8008    1    5    1    3
#
#                      abs_lat    lat     lon    lcm      pa    dcen
# Date Time
# 1976-01-01 00:00:00     8.40  -8.40   33.95  36.89  261.68  0.6024
# 1976-12-31 23:59:59     8.40  -8.40   33.95  36.89  261.68  0.6024
# 1977-01-01 00:00:00     8.40  -8.40   33.95  36.89  261.68  0.6024
# 1976-01-12 12:11:35     8.40  -8.40   33.95  36.89  261.68  0.6024
# 1976-01-14 01:13:30    10.25 -10.25  283.47 -53.28   99.54  0.8006
# ...                      ...    ...     ...    ...     ...     ...
# 1996-12-21 05:57:00     4.37   4.37  238.95  36.58  279.59  0.6050
# 1996-12-22 08:10:00     5.32   5.32  252.25  64.27  276.79  0.9052
# 1996-12-22 08:10:00     4.35   4.35  240.19  52.21  276.94  0.7959
# 1996-12-23 02:35:00     5.18   5.18  240.00  62.02  276.89  0.8878
# 1996-12-24 11:16:49    18.96 -18.96  168.17   8.23  205.06  0.3212
#
# [32697 rows x 18 columns]

# %%
df
# Out:
#                      i    yr  mo  da  hr  mi  se    id  pr1  pr2   ua   ws  \
# Date Time
# 1976-01-01 00:00:00  g  1976   1   1   0   0   0   675    4    9    3    5
# 1976-12-31 23:59:59  g  1976  12  31  23  59  59   675    4    9    3    5
# 1977-01-01 00:00:00  g  1977   1   1   0   0   0   675    4    9    3    5
# 1976-01-12 12:11:35  g  1976   1  12  12  11  35   675    4    9    3    5
# 1976-01-14 01:13:30  g  1976   1  14   1  13  30   676  128  700  106  581
# ...                 ..   ...  ..  ..  ..  ..  ..   ...  ...  ...  ...  ...
# 1996-12-21 05:57:00  g  1996  12  21   5  57   0  8007    3   23    2   14
# 1996-12-22 08:10:00  g  1996  12  22   8  10   0  8004   15   82   17   95
# 1996-12-22 08:10:00  g  1996  12  22   8  10   0  8007    4   20    3   16
# 1996-12-23 02:35:00  g  1996  12  23   2  35   0  8007    2   11    2   13
# 1996-12-24 11:16:49  g  1996  12  24  11  16  49  8008    1    5    1    3
#
#                      abs_lat    lat     lon    lcm      pa    dcen
# Date Time
# 1976-01-01 00:00:00     8.40  -8.40   33.95  36.89  261.68  0.6024
# 1976-12-31 23:59:59     8.40  -8.40   33.95  36.89  261.68  0.6024
# 1977-01-01 00:00:00     8.40  -8.40   33.95  36.89  261.68  0.6024
# 1976-01-12 12:11:35     8.40  -8.40   33.95  36.89  261.68  0.6024
# 1976-01-14 01:13:30    10.25 -10.25  283.47 -53.28   99.54  0.8006
# ...                      ...    ...     ...    ...     ...     ...
# 1996-12-21 05:57:00     4.37   4.37  238.95  36.58  279.59  0.6050
# 1996-12-22 08:10:00     5.32   5.32  252.25  64.27  276.79  0.9052
# 1996-12-22 08:10:00     4.35   4.35  240.19  52.21  276.94  0.7959
# 1996-12-23 02:35:00     5.18   5.18  240.00  62.02  276.89  0.8878
# 1996-12-24 11:16:49    18.96 -18.96  168.17   8.23  205.06  0.3212
#
# [32697 rows x 18 columns]

# %% [markdown]
# - Scatter-plot absolute-value of sunspot group latitude (you created above).
# - Resample this quantity in time, with 1-year intervals, taking the mean over each bin.
# - Plot 1-year-averaged latitudes you produced.
# - Plot errorbars that show the standard deviation.
# - On a duplicate scatter-plot with resampled data, plot errorbars that show standard deviation of the mean (check wikipedia for this, if you don't know).

# %%
plt.scatter(df.index, df["abs_lat"], s=.2, c="Gray")

# %%
new_df = pd.Series(np.array(df['abs_lat']), index = df.index)
new_df
# Out:
# Date Time
# 1976-01-01 00:00:00     8.40
# 1976-12-31 23:59:59     8.40
# 1977-01-01 00:00:00     8.40
# 1976-01-12 12:11:35     8.40
# 1976-01-14 01:13:30    10.25
#                        ...
# 1996-12-21 05:57:00     4.37
# 1996-12-22 08:10:00     5.32
# 1996-12-22 08:10:00     4.35
# 1996-12-23 02:35:00     5.18
# 1996-12-24 11:16:49    18.96
# Length: 32697, dtype: float64

# %%
new_df = new_df.resample('Y').mean()
new_df
# Out:
# Date Time
# 1976-12-31    13.551263
# 1977-12-31    22.084758
# 1978-12-31    21.342727
# 1979-12-31    18.283740
# 1980-12-31    16.050085
# 1981-12-31    13.631877
# 1982-12-31    12.277403
# 1983-12-31    12.681149
# 1984-12-31    11.091400
# 1985-12-31     8.898377
# 1986-12-31    10.488603
# 1987-12-31    24.209576
# 1988-12-31    21.954519
# 1989-12-31    19.499364
# 1990-12-31    17.111704
# 1991-12-31    14.589062
# 1992-12-31    12.984868
# 1993-12-31    11.613688
# 1994-12-31    10.043320
# 1995-12-31     9.897238
# 1996-12-31     9.679548
# Freq: A-DEC, dtype: float64

# %%
plt.scatter(df.index,df["abs_lat"],s =.2, c = "Gray" , alpha = 0.5)
plt.scatter(new_df.index,new_df,c="red", s = 30)

# %%
new_df2 = pd.Series(np.array(df['abs_lat']), index = df.index)
new_df2
# Out:
# Date Time
# 1976-01-01 00:00:00     8.40
# 1976-12-31 23:59:59     8.40
# 1977-01-01 00:00:00     8.40
# 1976-01-12 12:11:35     8.40
# 1976-01-14 01:13:30    10.25
#                        ...
# 1996-12-21 05:57:00     4.37
# 1996-12-22 08:10:00     5.32
# 1996-12-22 08:10:00     4.35
# 1996-12-23 02:35:00     5.18
# 1996-12-24 11:16:49    18.96
# Length: 32697, dtype: float64

# %%
new_df2 = new_df2.resample('Y').std()
new_df2
# Out:
# Date Time
# 1976-12-31     9.746413
# 1977-12-31     6.368392
# 1978-12-31     6.689896
# 1979-12-31     7.378116
# 1980-12-31     7.072644
# 1981-12-31     6.511074
# 1982-12-31     5.839704
# 1983-12-31     5.682539
# 1984-12-31     4.329891
# 1985-12-31     4.966813
# 1986-12-31    10.491839
# 1987-12-31     8.074396
# 1988-12-31     6.460602
# 1989-12-31     6.665567
# 1990-12-31     7.920368
# 1991-12-31     7.221985
# 1992-12-31     5.993044
# 1993-12-31     5.121965
# 1994-12-31     4.093632
# 1995-12-31     4.561350
# 1996-12-31     6.988213
# Freq: A-DEC, dtype: float64

# %%
plt.scatter(df.index,df["abs_lat"],s =.2, c = "Gray" , alpha = 0.5)
plt.scatter(new_df.index,new_df,c="red", s = 30)
plt.errorbar(new_df.index,new_df,yerr= new_df2,c="purple")
# Out:
# <ErrorbarContainer object of 3 artists>

# %% [markdown]
# - Scatter-plot sunspot group area (ws)
# - Calculate rolling maxima with a 1-year window (or 365 days).

# %%
plt.scatter(df.index,df['ws'],s=.2,c='Blue')

# %%
df["ws"].rolling(365).max().plot()
